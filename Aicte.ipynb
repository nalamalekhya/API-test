# %% [markdown]
# <a href="https://colab.research.google.com/github/nalamalekhya/API-test/blob/main/Aicte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_csv('/content/shopping_trends_dataset.csv')

# %%
df
# Out:
#     Index Order ID Cust ID  Gender  Age Age Group        Date    Month  \
# 0       1  ORD1000   CUST1    Male   22     18-25  2024-01-01  January
# 1       2  ORD1001   CUST2  Female   34     26-35  2024-01-02  January
# 2       3  ORD1002   CUST3    Male   29     26-35  2024-01-03  January
# 3       4  ORD1003   CUST4  Female   41     36-45  2024-01-04  January
# 4       5  ORD1004   CUST5    Male   18     18-25  2024-01-05  January
# 5       6  ORD1005   CUST6  Female   35     26-35  2024-01-06  January
# 6       7  ORD1006   CUST7    Male   28     26-35  2024-01-07  January
# 7       8  ORD1007   CUST8  Female   50     46-55  2024-01-08  January
# 8       9  ORD1008   CUST9    Male   23     18-25  2024-01-09  January
# 9      10  ORD1009  CUST10  Female   40     36-45  2024-01-10  January
# 10     11  ORD1010  CUST11    Male   31     26-35  2024-01-11  January
# 11     12  ORD1011  CUST12  Female   22     18-25  2024-01-12  January
# 12     13  ORD1012  CUST13    Male   26     26-35  2024-01-13  January
# 13     14  ORD1013  CUST14  Female   33     26-35  2024-01-14  January
# 14     15  ORD1014  CUST15    Male   48     46-55  2024-01-15  January
# 15     16  ORD1015  CUST16  Female   37     36-45  2024-01-16  January
# 16     17  ORD1016  CUST17    Male   19     18-25  2024-01-17  January
# 17     18  ORD1017  CUST18  Female   45     46-55  2024-01-18  January
# 18     19  ORD1018  CUST19    Male   39     36-45  2024-01-19  January
# 19     20  ORD1019  CUST20  Female   30     26-35  2024-01-20  January
#
#        Status    SKU     Category Size  Qty
# 0   Completed   SKU1     Clothing    M    1
# 1   Cancelled   SKU2  Electronics    L    2
# 2   Completed   SKU3     Footwear    S    1
# 3   Completed   SKU4  Accessories   XL    3
# 4    Returned   SKU5     Clothing    M    2
# 5   Completed   SKU6     Clothing    M    1
# 6   Cancelled   SKU7  Electronics    L    2
# 7   Completed   SKU8     Footwear    S    1
# 8   Completed   SKU9  Accessories   XL    3
# 9    Returned  SKU10     Clothing    M    2
# 10  Completed  SKU11     Clothing    M    1
# 11  Cancelled  SKU12  Electronics    L    2
# 12  Completed  SKU13     Footwear    S    1
# 13  Completed  SKU14  Accessories   XL    3
# 14   Returned  SKU15     Clothing    M    2
# 15  Completed  SKU16     Clothing    M    1
# 16  Cancelled  SKU17  Electronics    L    2
# 17  Completed  SKU18     Footwear    S    1
# 18  Completed  SKU19  Accessories   XL    3
# 19   Returned  SKU20     Clothing    M    2

# %%
df.shape
# Out:
# (20, 13)

# %% [markdown]
# df.info()

# %%
pd.isnull(df).sum()
# Out:
# Index        0
# Order ID     0
# Cust ID      0
# Gender       0
# Age          0
# Age Group    0
# Date         0
# Month        0
# Status       0
# SKU          0
# Category     0
# Size         0
# Qty          0
# dtype: int64

# %%
duplicate_record= df.duplicated()
print(duplicate_record)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.drop_duplicates(inplace= True)

# %%
df.columns
# Out:
# Index(['Index', 'Order ID', 'Cust ID', 'Gender', 'Age', 'Age Group', 'Date',
#        'Month', 'Status', 'SKU', 'Category', 'Size', 'Qty'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Index Order ID Cust ID  Gender  Age Age Group        Date    Month  \
# 0       1  ORD1000   CUST1    Male   22     18-25  2024-01-01  January
# 1       2  ORD1001   CUST2  Female   34     26-35  2024-01-02  January
# 2       3  ORD1002   CUST3    Male   29     26-35  2024-01-03  January
# 3       4  ORD1003   CUST4  Female   41     36-45  2024-01-04  January
# 4       5  ORD1004   CUST5    Male   18     18-25  2024-01-05  January
# 5       6  ORD1005   CUST6  Female   35     26-35  2024-01-06  January
# 6       7  ORD1006   CUST7    Male   28     26-35  2024-01-07  January
# 7       8  ORD1007   CUST8  Female   50     46-55  2024-01-08  January
# 8       9  ORD1008   CUST9    Male   23     18-25  2024-01-09  January
# 9      10  ORD1009  CUST10  Female   40     36-45  2024-01-10  January
# 10     11  ORD1010  CUST11    Male   31     26-35  2024-01-11  January
# 11     12  ORD1011  CUST12  Female   22     18-25  2024-01-12  January
# 12     13  ORD1012  CUST13    Male   26     26-35  2024-01-13  January
# 13     14  ORD1013  CUST14  Female   33     26-35  2024-01-14  January
# 14     15  ORD1014  CUST15    Male   48     46-55  2024-01-15  January
# 15     16  ORD1015  CUST16  Female   37     36-45  2024-01-16  January
# 16     17  ORD1016  CUST17    Male   19     18-25  2024-01-17  January
# 17     18  ORD1017  CUST18  Female   45     46-55  2024-01-18  January
# 18     19  ORD1018  CUST19    Male   39     36-45  2024-01-19  January
# 19     20  ORD1019  CUST20  Female   30     26-35  2024-01-20  January
#
#        Status    SKU     Category Size  Qty
# 0   Completed   SKU1     Clothing    M    1
# 1   Cancelled   SKU2  Electronics    L    2
# 2   Completed   SKU3     Footwear    S    1
# 3   Completed   SKU4  Accessories   XL    3
# 4    Returned   SKU5     Clothing    M    2
# 5   Completed   SKU6     Clothing    M    1
# 6   Cancelled   SKU7  Electronics    L    2
# 7   Completed   SKU8     Footwear    S    1
# 8   Completed   SKU9  Accessories   XL    3
# 9    Returned  SKU10     Clothing    M    2
# 10  Completed  SKU11     Clothing    M    1
# 11  Cancelled  SKU12  Electronics    L    2
# 12  Completed  SKU13     Footwear    S    1
# 13  Completed  SKU14  Accessories   XL    3
# 14   Returned  SKU15     Clothing    M    2
# 15  Completed  SKU16     Clothing    M    1
# 16  Cancelled  SKU17  Electronics    L    2
# 17  Completed  SKU18     Footwear    S    1
# 18  Completed  SKU19  Accessories   XL    3
# 19   Returned  SKU20     Clothing    M    2  >

# %%
df.describe()
# Out:
#           Index        Age        Qty
# count  20.00000  20.000000  20.000000
# mean   10.50000  32.500000   1.800000
# std     5.91608   9.428401   0.767772
# min     1.00000  18.000000   1.000000
# 25%     5.75000  25.250000   1.000000
# 50%    10.50000  32.000000   2.000000
# 75%    15.25000  39.250000   2.000000
# max    20.00000  50.000000   3.000000

# %%
# plotting bar chart for gender and its count
gb= df.groupby(['Gender'], as_index= False) ['Order ID'].count().sort_values(by= 'Gender', ascending= False)
ax = plt.pie(gb['Order ID'], labels=gb['Gender'], autopct='%1.1f%%', startangle=140, colors=['red', 'blue'])
plt.show()

# %%
# plotting count plot to check count of gender in each age group
ax = sns.countplot(x='Age Group', data = df, hue= 'Gender')
plt.title('Age Group')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
gb= df.groupby(['Status'], as_index= False) ['Order ID'].count().sort_values(by= 'Status', ascending= False)
ax = plt.pie(gb['Order ID'], labels=gb['Status'], autopct='%1.1f%%', startangle=140, colors=['red', 'orange', 'green', 'blue'])
plt.show()

# %%
ax = sns.countplot(x='Category', data = df, hue= 'Category',order= df['Category'].value_counts().index)
plt.title('Category')
for bars in ax.containers:
    ax.bar_label(bars)
sns.set(rc={'figure.figsize':(20,5)})

# %%
# plotting countplot to know Size with most sales
gb= df.groupby(['Size'], as_index= False) ['Order ID'].count().sort_values(by= 'Order ID', ascending= False)
ax= sns.barplot(x= 'Size', y='Order ID', data= gb, hue = 'Size')
plt.title('Size')
sns.set(rc={'figure.figsize':(20,5)})
